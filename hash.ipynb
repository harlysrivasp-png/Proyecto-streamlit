# %%
import streamlit_authenticator as stauth
import yaml
from yaml.loader import SafeLoader
# Out:
# 2026-05-25 22:31:35.563 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-05-25 22:31:35.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-25 22:31:35.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-25 22:31:35.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-25 22:31:35.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
with open('config.yaml') as file:
    
    config = yaml.load(
        file,
        Loader=SafeLoader
    )
stauth.Hasher.hash_passwords(config['credentials'])
# Out:
# {'usernames': {'dsolar': {'email': 'dsolre@gmail.com',
#    'failed_login_attempts': 0,
#    'first_name': 'David',
#    'last_name': 'Soler',
#    'logged_in': False,
#    'password': '$2b$12$Pmy1W.IAhX2Adl29z.p27.Z2I6H5AmJsMi8JKuWP4UnadszIKu0ui',
#    'roles': ['admin', 'editor', 'viewer']},
#   'rbriggs': {'email': 'rbriggs@gmail.com',
#    'failed_login_attempts': 0,
#    'first_name': 'Rebeca',
#    'last_name': 'Briggs',
#    'logged_in': False,
#    'password': '$2b$12$fdo2z8BjGQMiuyXciJDETOljf9j4fK2JkN5WHXppz1h.20.J25tre',
#    'roles': ['viewer']}}}
